# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot
from keras.datasets import mnist 

(train_X, train_y), (test_X, test_y) = mnist.load_data()

# %%
pyplot.imshow(train_X[5], cmap=pyplot.get_cmap('viridis'))
pyplot.axis('off')
pyplot.show()
